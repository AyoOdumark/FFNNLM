# %%
from process_data import read_file, clean_data, tokenize, word_frequency
import pandas as pd
from operator import itemgetter

# %%
corpus = read_file(".\\Brown.txt")
corpus = [clean_data(line) for line in corpus]
corpus = [tokenize(line) for line in corpus]

# %%
word_freq_map = word_frequency(corpus)

# %%
# Sort the dictionary
for k, v in sorted(word_freq_map.items(), key=lambda item: item[1]):
    print(k, v)
# Out:
# termend 1
# presentments 1
# septemberoctober 1
# durwood 1
# pye 1
# mayornominate 1
# inure 1
# reset 1
# disable 1
# ordinarys 1
# appraisers 1
# juries 1
# unmeritorious 1
# extern 1
# bellwood 1
# alpharetta 1
# cheshire 1
# amicable 1
# 637 1
# expires 1
# dorsey 1
# ledford 1
# gainesville 1
# schley 1
# 8731 1
# 295. 1
# mac 1
# 1,119 1
# 402. 1
# calmest 1
# callan 1
# tabb 1
# erase 1
# depositors 1
# gaynor 1
# brady 1
# harlingen 1
# bexar 1
# tarrant 1
# 451,500 1
# 157,460 1
# 88,000 1
# 182 1
# scholastics 1
# parimutuels 1
# berrys 1
# exgambler 1
# validated 1
# crump 1
# saba 1
# notarized 1
# aikin 1
# formby 1
# plainview 1
# formbys 1
# referendum 1
# seminole 1
# hollowell 1
# cottens 1
# dumas 1
# eligio 1
# kika 1
# garza 1
# juniorsenior 1
# cosigners 1
# mclemore 1
# okla 1
# letterman 1
# raymondville 1
# strickland 1
# 4.4 1
# pirie 1
# breakups 1
# allwoman 1
# freeforall 1
# midmorning 1
# pertained 1
# wrongful 1
# miscount 1
# 33d 1
# 42d 1
# ...

# %%
word_freq_map["amicable"]
# Out:
# 1
